# %%
# !pip install biopython
# !pip install reportlab
# !pip install nglview
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for nglview: filename=nglview-3.0.3-py3-none-any.whl size=8057564 sha256=87ce17e1359c8c516333b2cc12e9dfe025af4a9cf762b0e257ea208e6217e3d8
#   Stored in directory: c:\users\diego\appdata\local\pip\cache\wheels\ed\12\ba\4e227d89934c5d7bdf91387286e45dc868613ab32fa6ce36cf
# Successfully built nglview
# ...
